# %% [markdown]
# ##  텍스트 요약(Text Summarization) : Attention 사용

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# #### 데이터 가져오기

# %%
data = pd.read_csv("/content/drive/My Drive/NLP_LAB/Reviews.csv", nrows = 100000) 

# data = pd.read_csv("Reviews.csv", nrows = 100000) # 56만개중에서 10만개 만 읽어옴
len(data)
# Out:
# 100000

# %%
data.head()
# Out:
#    Id  ...                                               Text
# 0   1  ...  I have bought several of the Vitality canned d...
# 1   2  ...  Product arrived labeled as Jumbo Salted Peanut...
# 2   3  ...  This is a confection that has been around a fe...
# 3   4  ...  If you are looking for the secret ingredient i...
# 4   5  ...  Great taffy at a great price.  There was a wid...
#
# [5 rows x 10 columns]

# %%
data = data[['Text','Summary']]
data.head()
# Out:
#                                                 Text                Summary
# 0  I have bought several of the Vitality canned d...  Good Quality Dog Food
# 1  Product arrived labeled as Jumbo Salted Peanut...      Not as Advertised
# 2  This is a confection that has been around a fe...  "Delight" says it all
# 3  If you are looking for the secret ingredient i...         Cough Medicine
# 4  Great taffy at a great price.  There was a wid...            Great taffy

# %%
data.sample(10)
# Out:
#                                                     Text                                       Summary
# 19696  I'm sure this Mama Grain is pretty healthy but...                                        YUCK!!
# 76963  I got this today, and it couldn't have come at...                                  Great snack!
# 93739  The bars are good but not great.  They are han...                                    Ok product
# 69239  It took me a decade of yo-yo dieting on variou...         "Health" Does Not Always Equal Health
# 18977  I buy this tea for my wife. This is perhaps he...                        My wife loves this tea
# 57055  This is really awesome chili. Preperation time...                          This stuff kicks ass
# 63824  I have been drinking Melitta Lite for about 5 ...  Lite on Caffeine and Acidity, FULL on Flavor
# 94112  I've been buying this product for over 10 yrs....                                  Dogs Love It
# 53556  i love this tea for dieting its the best i wil...                                     wonderful
# 85786  My dogs absolutely love these treats - we get ...                                Healthy Treats

# %% [markdown]
# ###  텍스트 전처리

# %%
print(data['Text'].nunique())
print(data['Summary'].nunique())
# Out:
# 88426
# 72348

# %%
data.drop_duplicates(subset=['Text'], inplace=True)
len(data)
# Out:
# 88426

# %%
print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
len(data)
# Out:
# 88425

# %%
# 줄임말(축약어)
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is", "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are", "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have", "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"}

# %%
# 불용어
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# 불용어
stop_words = set(stopwords.words('english'))
print('불용어 개수 :', len(stop_words))
print(stop_words)
# Out:
# 불용어 개수 : 179
# {"mustn't", 'she', 'y', "doesn't", 'm', 'her', 'into', 'yourself', 'out', 'can', 'didn', 'does', 'being', 'haven', "wasn't", 'mightn', "shouldn't", "she's", 'further', 'under', 'about', 'ma', 'at', 'who', 'nor', 'over', "isn't", 'or', 'before', 'him', "you'll", 'did', 'what', 'just', 'by', 'don', 'ourselves', 'this', 'but', 'above', "weren't", 'these', 'should', 'against', 'itself', 'll', 'now', 'me', 'doing', 'hers', 'd', "you'd", 'all', 'o', 'you', "wouldn't", 'hadn', 'too', 'am', 'he', 'here', 'couldn', "shan't", 'that', 'my', 'each', 'to', 's', 'once', 'with', 'ours', 'and', 'won', 'off', 'theirs', 'so', 'if', 'aren', 'during', "hasn't", 'after', 'then', 'most', 'doesn', "it's", "didn't", 'down', 'do', 'only', 'hasn', 'myself', 'himself', 'between', "that'll", 'own', "don't", 'are', 'shouldn', 'until', 'because', 'were', 'it', 'of', 'needn', 'other', "should've", 'from', 'those', 'isn', 'our', 'than', 'such', 'mustn', 'was', 'be', "aren't", 'both', 'herself', 'i', 'how', 'as', 'been', 'an', 'a', 'up', 'below', 'why', 'more', 'through', 'some', 'wasn', 'very', "couldn't", 'while', 've', 'shan', 'when', 'weren', "haven't", 'will', 'your', "won't", 'for', "mightn't", 'themselves', 'is', 'had', 'its', 'any', "needn't", 'the', 'yourselves', 'which', 'no', 'again', 'in', 'has', 'having', 'not', 'on', 'wouldn', 'they', 'there', 'ain', 're', 'have', 'them', 'where', 'same', 'few', 'whom', 'yours', 'his', "you're", "you've", "hadn't", 't', 'their', 'we'}

# %%
def preprocess_sentence(sentence, remove_stopwords = True):
    sentence = sentence.lower()                     # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence)   # 괄호로 닫힌 문자열  제거 Ex) my husband (and myself) for => my husband for
    sentence = re.sub('"','', sentence)             # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","",sentence)         # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence)  # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence)   # m이 2개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stop_words if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'
print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, 0))  # 불용어를 제거하지 않고 괄호로 닫힌 문자열을 제거한다
# Out:
# everything bought great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %%
clean_text = []
for s in data['Text']:
    clean_text.append(preprocess_sentence(s))
clean_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
clean_summary = []
for s in data['Summary']:
    clean_summary.append(preprocess_sentence(s, 0))
clean_summary[:5]
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: UserWarning: "http://www.amazon.com/gp/product/b007i7yygy/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy']

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# %%
data.replace('', np.nan, inplace=True)
print(data.isnull().sum())
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
data.dropna(axis = 0, inplace = True)
len(data)
# Out:
# 88355

# %%
# 길이 분포 시각화 
text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]


print('Text min : {}'.format(np.min(text_len)))
print('Text max : {}'.format(np.max(text_len)))
print('Text mean : {}'.format(np.mean(text_len)))
print('Summary min : {}'.format(np.min(summary_len)))
print('Summary max : {}'.format(np.max(summary_len)))
print('Summary mean : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')

plt.show()
# Out:
# Text min : 2
# Text max : 1235
# Text mean : 38.792428272310566
# Summary min : 1
# Summary max : 28
# Summary mean : 4.010729443721352

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.7745119121724859

# %%
below_threshold_len(summary_max_len, data['Summary'])
# Out:
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]       # Text의 길이가 50이하인 행 추출
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)] # Summary의 길이가 8이하인 행 추출 
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 65818

# %%
data.head()
# Out:
#                                                 Text                Summary
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy

# %%
data['Summary'] = data['Summary'].apply(lambda x : 'sostoken '+ x + ' eostoken')
data.head()
# Out:
#                                                 Text                                  Summary
# 0  bought several vitality canned dog food produc...  sostoken good quality dog food eostoken
# 1  product arrived labeled jumbo salted peanuts p...      sostoken not as advertised eostoken
# 2  confection around centuries light pillowy citr...    sostoken delight says it all eostoken
# 3  looking secret ingredient robitussin believe f...         sostoken cough medicine eostoken
# 4  great taffy great price wide assortment yummy ...            sostoken great taffy eostoken

# %%
Text_data = list(data['Text'])
Summary_data = list(data['Summary'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Text_data, Summary_data, test_size=0.2, random_state=0, shuffle=True)

print('X_train :', len(X_train))
print('y_train :',len(y_train))
print('X_test :',len(X_test))
print('y_test :',len(y_test))
# Out:
# X_train : 52654
# y_train : 52654
# X_test : 13164
# y_test : 13164

# %%
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(X_train)

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0                              # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0                            # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0                             # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 
for key, value in src_tokenizer.word_counts.items():  # word_counts :단어의 빈도
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('--X_train--')
print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# --X_train--
# 단어 집합(vocabulary)의 크기 : 31940
# 등장 빈도가 6번 이하인 희귀 단어의 수: 23707
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8233
# 단어 집합에서 희귀 단어의 비율: 74.22354414527238
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.3949897589412323

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words = src_vocab) 
src_tokenizer.fit_on_texts(X_train)


X_train = src_tokenizer.texts_to_sequences(X_train) 
X_test = src_tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:5])
# Out:
# [[4256, 611, 816, 4477, 528, 1540, 32, 45, 4, 79, 2281, 234, 19, 1157, 2923, 948, 1122, 996, 2, 153, 10, 43], [204, 15, 154, 51, 259, 60, 73, 24, 49, 17, 886, 259, 2, 29, 209, 14, 504, 2081, 420, 13, 86, 64, 22, 2464, 134, 14, 504, 86], [112, 1570, 2, 1771, 185, 39, 505, 112, 283], [296, 105, 496, 834, 69, 103, 334, 5082, 2294, 765, 7, 908, 585, 1489, 351, 5265, 100, 75, 1908, 137, 141, 585, 864, 5083, 89, 830, 564, 1772, 305, 254, 1541, 97, 247, 2, 1600, 2100, 92, 2645], [54, 1247, 806, 5, 497, 479, 46, 236, 1218, 381, 5, 3879, 3880, 172, 479, 46, 1247]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(y_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index)   # 단어의 수
rare_cnt = 0                                # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0                              # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0                               # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value
print('--y_train--')
print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# --y_train--
# 단어 집합(vocabulary)의 크기 : 10498
# 등장 빈도가 5번 이하인 희귀 단어의 수: 8126
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2372
# 단어 집합에서 희귀 단어의 비율: 77.40522004191274
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.833194065065198

# %%
tar_vocab = 1000
tar_tokenizer = Tokenizer(num_words = tar_vocab) 
tar_tokenizer.fit_on_texts(y_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
y_train = tar_tokenizer.texts_to_sequences(y_train) 
y_test = tar_tokenizer.texts_to_sequences(y_test)

# %%
print(y_train[:5])
type(y_train)
# Out:
# [[1, 805, 2], [1, 7, 298, 138, 86, 2], [1, 25, 745, 2], [1, 488, 39, 22, 30, 12, 2], [1, 15, 16, 238, 84, 35, 12, 2]]
# list

# %%
drop_train = [index for index, sentence in enumerate(y_train) if len(sentence) == 2]
drop_test = [index for index, sentence in enumerate(y_test) if len(sentence) == 2]

# %%
print('X_train :', len(X_train))
print('y_train :',len(y_train))
print('X_test :',len(X_test))
print('y_test :',len(y_test))
# Out:
# X_train : 52654
# y_train : 52654
# X_test : 13164
# y_test : 13164

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
X_test = np.delete(X_test, drop_test, axis=0)
y_test = np.delete(y_test, drop_test, axis=0)

print('X_train :', len(X_train))
print('y_train :',len(y_train))
print('X_test :',len(X_test))
print('y_test :',len(y_test))
X_test.shape
# Out:
# X_train : 50512
# y_train : 50512
# X_test : 12609
# y_test : 12609
# (12609,)

# %% [markdown]
# ### 토큰화와 패딩

# %%
X_train = pad_sequences(X_train, maxlen = text_max_len, padding='post')
X_test = pad_sequences(X_test, maxlen = text_max_len, padding='post')
y_train = pad_sequences(y_train, maxlen = summary_max_len, padding='post')
y_test = pad_sequences(y_test, maxlen = summary_max_len, padding='post')

# %% [markdown]
# ###  Seq2eq 와 Attention 사용 모델 구현

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 64
hidden_size = 128

# 인코더
encoder_inputs = Input(shape=(text_max_len,))  # text_max_len :50

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.0)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.0)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.0)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4, recurrent_dropout=0.0)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 64)       512000      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 128), (N 98816       embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 128), (N 131584      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 64)     64000       input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 128), (N 131584      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 128),  98816       embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1000)   129000      lstm_3[0][0]
# ==================================================================================================
# Total params: 1,165,800
# Trainable params: 1,165,800
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 깃허브에 공개된 attention.py 사용하기
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 64)       512000      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 128), (N 98816       embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 128), (N 131584      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 64)     64000       input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 128), (N 131584      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 128),  98816       embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 128),  32896       lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 256)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 1000)   257000      concat_layer[0][0]
# ==================================================================================================
# Total params: 1,326,696
# Trainable params: 1,326,696
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 2)

# 약 9분 소요(GPU)
history = model.fit([X_train, y_train[:,:-1]], y_train.reshape(y_train.shape[0], y_train.shape[1], 1)[:,1:] \
                  ,epochs=50, callbacks=[es], batch_size = 256, validation_data=([X_test, y_test[:,:-1]], \
                  y_test.reshape(y_test.shape[0], y_test.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 198/198 [==============================] - 11s 54ms/step - loss: 2.8257 - val_loss: 2.5351
# Epoch 2/50
# 198/198 [==============================] - 10s 48ms/step - loss: 2.4954 - val_loss: 2.4250
# Epoch 3/50
# 198/198 [==============================] - 10s 49ms/step - loss: 2.3896 - val_loss: 2.3532
# Epoch 4/50
# 198/198 [==============================] - 10s 48ms/step - loss: 2.3052 - val_loss: 2.2725
# Epoch 5/50
# 198/198 [==============================] - 10s 48ms/step - loss: 2.2249 - val_loss: 2.2264
# Epoch 6/50
# 198/198 [==============================] - 10s 49ms/step - loss: 2.1533 - val_loss: 2.1426
# Epoch 7/50
# 198/198 [==============================] - 10s 49ms/step - loss: 2.0942 - val_loss: 2.1162
# Epoch 8/50
# 198/198 [==============================] - 10s 48ms/step - loss: 2.0447 - val_loss: 2.0662
# Epoch 9/50
# 198/198 [==============================] - 10s 48ms/step - loss: 2.0047 - val_loss: 2.0400
# Epoch 10/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.9702 - val_loss: 2.0158
# Epoch 11/50
# 198/198 [==============================] - 9s 48ms/step - loss: 1.9413 - val_loss: 1.9999
# Epoch 12/50
# 198/198 [==============================] - 10s 48ms/step - loss: 1.9173 - val_loss: 1.9874
# Epoch 13/50
# 198/198 [==============================] - 10s 48ms/step - loss: 1.8952 - val_loss: 1.9861
# Epoch 14/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.8748 - val_loss: 1.9684
# Epoch 15/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.8556 - val_loss: 1.9514
# Epoch 16/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.8372 - val_loss: 1.9555
# Epoch 17/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.8202 - val_loss: 1.9370
# Epoch 18/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.8040 - val_loss: 1.9343
# Epoch 19/50
# 198/198 [==============================] - 10s 48ms/step - loss: 1.7889 - val_loss: 1.9305
# Epoch 20/50
# 198/198 [==============================] - 10s 48ms/step - loss: 1.7732 - val_loss: 1.9223
# Epoch 21/50
# 198/198 [==============================] - 10s 48ms/step - loss: 1.7604 - val_loss: 1.9206
# Epoch 22/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.7462 - val_loss: 1.9121
# Epoch 23/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.7341 - val_loss: 1.9144
# Epoch 24/50
# 198/198 [==============================] - 10s 49ms/step - loss: 1.7211 - val_loss: 1.9130
# Epoch 00024: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ###  Test

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])
encoder_model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 64)            512000
# _________________________________________________________________
# lstm (LSTM)                  [(None, 50, 128), (None,  98816
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 50, 128), (None,  131584
# _________________________________________________________________
# lstm_2 (LSTM)                [(None, 50, 128), (None,  131584
# =================================================================
# Total params: 873,984
# Trainable params: 873,984
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

decoder_model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 64)     64000       input_2[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 128),  98816       embedding_1[1][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 50, 128)]    0
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 128),  32896       input_5[0][0]
#                                                                  lstm_3[1][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, None, 256)    0           lstm_3[1][0]
#                                                                  attention_layer[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 1000)   257000      concat[0][0]
# ==================================================================================================
# Total params: 452,712
# Trainable params: 452,712
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if(i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(X_test[i]))
    print("실제 요약문 :",seq2summary(y_test[i]))
    print("예측 요약문 :",decode_sequence(X_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 :  dirty martini olive husband loves martini like people jars olives juice read company online actually cheaper order amazon husband fussy martini drinker loves amazing save buying lots jars olives never get used give try disappointed
# 실제 요약문 : if you like
# 예측 요약문 :  great product
#
#
# 원문 :  impressed tuna ok companies efforts ended giving cans away used meal usually like tuna oil thought flavor lacking think tuna canned juices much better wild planet caught wild tuna ounce cans
# 실제 요약문 : did not like too much
# 예측 요약문 :  not as good as
#
#
# 원문 :  coffee excellent delivered makes count lasts long enough two us month definitely keep coming
# 실제 요약문 : good coffee
# 예측 요약문 :  great coffee
#
#
# 원문 :  buying coffee least years love smooth taste hint hazelnut friends enjoy coming good cup coffee
# 실제 요약문 : great coffee
# 예측 요약문 :  coffee
#
#
# 원문 :  tried coffee wonderful smooth rich full flavored bold would recommend anyone
# 실제 요약문 : great coffee
# 예측 요약문 :  coffee
#
#
# 원문 :  never problem anything amazon ordered cases earth best baby food tasty nutritious variety offer grams protein iron subscribe save cannot get enough eats everyday
# 실제 요약문 : my son loves these
# 예측 요약문 :  good food
#
#
# 원문 :  bad season impossible find canned pumpkin store thrilled find amazon com make many yummy things would made item amazon com farmer market foods organic canned pumpkin ounce cans
# 실제 요약문 : canned organic pumpkin
# 예측 요약문 :  great gift
#
#
# 원문 :  good cup coffee looking nice cup wake light blend overpowering taste prefer bolder blends husband likes light compromise blend enjoy much
# 실제 요약문 : good cup of coffee
# 예측 요약문 :  good coffee
#
#
# 원문 :  love crisp sugar cookies perfect tasted like regular gluten cookies buy
# 실제 요약문 : love these cookies
# 예측 요약문 :  great cookies
#
#
# 원문 :  dried dog treats great dog diabetes low fat treat loves
# 실제 요약문 : great for dog
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  actual product fine expensive purchase way could find locally needed company great deal
# 실제 요약문 : salt
# 예측 요약문 :  great product
#
#
# 원문 :  cats ranging age years years love used feed another brand food introduced food could get enough eating food exclusively least years none ever sick
# 실제 요약문 : my cats love this
# 예측 요약문 :  cats love it
#
#
# 원문 :  first things delicious however opening without making mess nearly impossible super crumbly open package care buy many good options way less messy
# 실제 요약문 : delicious but messy
# 예측 요약문 :  not as advertised
#
#
# 원문 :  greenies ordered amazon less expensive mortar stores plan order another box received product days placing order terrific product lab loves treat
# 실제 요약문 : terrific product for doggie
# 예측 요약문 :  greenies
#
#
# 원문 :  ordered family could familiar taste home excited product fresh pleased
# 실제 요약문 : very pleased
# 예측 요약문 :  great product
#
#
# 원문 :  received sample product try tell program pre made food course taste like homemade said ok grams fiber nice nice convenient snack trying watch weight boost fiber banana nut really favorite flavor think would like better came cinnamon apple
# 실제 요약문 : it is okay but not fantastic
# 예측 요약문 :  good but not my favorite
#
#
# 원문 :  tree totally brown appears dead quite funky hope may sprout something spring
# 실제 요약문 : not sure about this one
# 예측 요약문 :  not what expected
#
#
# 원문 :  fizzy fruity soda tastes great added sugars tastes great think lo cal drink nope cal per added vitamin like fruit mixes main juice apple grape kiwi strawberry raspberry listed ingredients thought could taste flavors beyond apple grape combo well
# 실제 요약문 : excellent product
# 예측 요약문 :  refreshing
#
#
# 원문 :  love dolce gusto cast eye number choices machines caramel latte tast addition limited selection definately buy
# 실제 요약문 : tasty addition to selection
# 예측 요약문 :  great product
#
#
# 원문 :  received order twinings earl grey cups today tried one tonight wow disappointed say least funky smell taste aftertaste compared bigelow earl grey cups want earl grey created equal edit left review decaf earl grey ordered regular blend oops
# 실제 요약문 : not my cup of tea
# 예측 요약문 :  not bad
#
#
# 원문 :  syrup excellent quality great shame need two well great syrup non less
# 실제 요약문 : the son
# 예측 요약문 :  great syrup
#
#
# 원문 :  dr zevia may favorite zevia flavors think tastes like diet dr pepper stevia aftertaste minimal zevia flavors would highly recommend dr zevia
# 실제 요약문 : delicious
# 예측 요약문 :  great taste
#
#
# 원문 :  great product shipping time great one bottles leaked happens kind container
# 실제 요약문 : agave nectar
# 예측 요약문 :  great product
#
#
# 원문 :  coffee taste like pleased purchase know costs met coffee expensive time doorstep unfortunately cannot always buy things would like buy due mentioned regular basis
# 실제 요약문 : coffee lover
# 예측 요약문 :  great coffee
#
#
# 원문 :  tea strong weird taste like fragrant jasmine tea use contacted seller since product expiration date seller refuse exchange
# 실제 요약문 : weird taste
# 예측 요약문 :  tea
#
#
# 원문 :  exact noodles used main staple dish fix family every christmas getting harder harder find noodles local grocery glad find line thank amazon com making find
# 실제 요약문 : perfect ingredient
# 예측 요약문 :  great gluten free pasta
#
#
# 원문 :  much buttery taste light butter popcorns far best light popcorn tasted
# 실제 요약문 : great taste
# 예측 요약문 :  great taste
#
#
# 원문 :  love crackers even serve non gluten free eaters great success multi grain crackers fennel seeds like taste fennel sure get one two flavors original flavor tastes like cross ritz cracker two favorite crackers found could gluten
# 실제 요약문 : love all flavors
# 예측 요약문 :  great alternative to regular crackers
#
#
# 원문 :  good friend mine always told much loved gum well found gave left packs unfortunately recently died brain found gum yesterday toast love miss much
# 실제 요약문 : great gum in
# 예측 요약문 :  not as good as
#
#
# 원문 :  blend really full bodied bitterness solid cup get going morning brand good going try varieties price great value
# 실제 요약문 : good morning cup
# 예측 요약문 :  great coffee
#
#
# 원문 :  sure cook pasta completely taste great holds sauce well
# 실제 요약문 : good product
# 예측 요약문 :  great pasta
#
#
# 원문 :  first tried germany purchased bags bring home ran quickly pleased find could order amazon try disappointed put chicken noodle soup least times week
# 실제 요약문 : addicted
# 예측 요약문 :  great product
#
#
# 원문 :  yr old fussy appetite used wellness many well known brands used past past pets loves blue buffalo also purchased blue buffalo cat loves also natural grain products protein beginning list corn oil etc price comparable name brands
# 실제 요약문 : my
# 예측 요약문 :  my cat loves this
#
#
# 원문 :  sure going one gag health items found brewer yeast quite palatable sprinkle bit brewer yeast mixed soy sauce green beans almost good favorite yeast flakes snob cat fan though figures
# 실제 요약문 : surprisingly tasty
# 예측 요약문 :  not good
#
#
# 원문 :  gustaf wine gums things like gummis none like fruit flavors chewy snacks wine gums chewy fruit flavor quite sweet gummi snacks care things make fingers sticky wine gums texture like swedish fish
# 실제 요약문 : tasty change of
# 예측 요약문 :  not bad
#
#
# 원문 :  brands earl grey stash favorite double bergamot best flavor fantastic past difficult time finding stores shop price least dollar box like flavorful tea like one cannot go wrong one
# 실제 요약문 : my favorite
# 예측 요약문 :  great tea
#
#
# 원문 :  pumpkin seeds yummy first thought small wrong perfect size come oz bags makes perfect taking car kids loved overly salted lightly best part crispy soft bland like shelf somewhere ages perfect buy
# 실제 요약문 : crispy yummy perfect size
# 예측 요약문 :  great gift
#
#
# 원문 :  dogs food three years well
# 실제 요약문 : healthy choice
# 예측 요약문 :  dogs love it
#
#
# 원문 :  ener foods english muffins ounce units one favorite gluten free items regular item keep hand take lunch toast filling easy cheaper going fast food places use mini pizzas buns bacon egg cheese sandwich breakfast chicken sandwiches etc easy take trips friends family eat must toast bake best favor
# 실제 요약문 : foods english muffins
# 예측 요약문 :  great for
#
#
# 원문 :  great deal great coffee drink every morning great flavor great price
# 실제 요약문 : great coffee
# 예측 요약문 :  great coffee
#
#
# 원문 :  happy found wonderful decaf tea guests tea nice full flavored smooth finish usually use cup twice setting tea remains true delicious price best found anywhere
# 실제 요약문 : mm good tea
# 예측 요약문 :  great tea
#
#
# 원문 :  product used affordable price increase fewer boxes definitely worth
# 실제 요약문 : price
# 예측 요약문 :  great product
#
#
# 원문 :  got bbq popchips amazon promotion price came taste good wish less salty would certainly purchase came less salty version
# 실제 요약문 : tasty but wish it was less salty
# 예측 요약문 :  not bad
#
#
# 원문 :  great fresh finishing salt personally prefer murray river pink salt delicate crunch like change try
# 실제 요약문 : very large
# 예측 요약문 :  great product
#
#
# 원문 :  would prefer drink regular lavazza time cannot handle caffeine use good coffee
# 실제 요약문 : solid decaf
# 예측 요약문 :  good coffee
#
#
# 원문 :  bought color cake cup made using color first time say perfect afraid silver would dark sheen exactly hoping
# 실제 요약문 : love it
# 예측 요약문 :  great product
#
#
# 원문 :  dog loves local grocery stores raised price bag saw subscribe save program signed
# 실제 요약문 : great deal
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  happy baby products best yogurt melts messy great give toddler snack organic real fruit inside happy baby customer service great everytime contact question respond within day much info
# 실제 요약문 : are great
# 예측 요약문 :  great for baby
#
#
# 원문 :  wife must classic simple english tea nothing else nice able order items like keep hand one source amazon
# 실제 요약문 : nothing else will do
# 예측 요약문 :  tea
#
#
# 원문 :  dog loves stuff ground sprinkled dry food gobbles additives fillers carbs also use treat best price amazon quick delivery
# 실제 요약문 : great
# 예측 요약문 :  great dog food
#
#
# 원문 :  personally care coffee mild little nutty flavor stick tully kona house blends also emeril big easy bold
# 실제 요약문 : coffee
# 예측 요약문 :  coffee
#
#
# 원문 :  love product normally color shampoo hair makes stiff dove products including color shampoo keep hair soft moist definitely recommend product friends
# 실제 요약문 : great shampoo
# 예측 요약문 :  tea
#
#
# 원문 :  enjoy manufacturer dried apricots plums much thought would give peaches try however disappointed sweet dry hard chew
# 실제 요약문 : texture and taste
# 예측 요약문 :  not bad
#
#
# 원문 :  bought device use brand new sure noise feedback received device horrible might bad unit called customer service real person answered right away offered getting new unit see process goes update review
# 실제 요약문 : still up in the
# 예측 요약문 :  bad
#
#
# 원문 :  oh man love candy super delicious really sour would always giant quarters spend cents
# 실제 요약문 : delicious
# 예측 요약문 :  best candy ever
#
#
# 원문 :  product arrived broken pieces flavor good actually threw garbage disappointing
# 실제 요약문 : very disappointed
# 예측 요약문 :  stale
#
#
# 원문 :  switching gerber helped reduce baby spit issues almost much switching enfamil similac originally gotten acid reflux prescription switching similac spit nut rice really need anymore love stuff read somewhere gerber rice extra kosher ingredients sure related definitely sticking nut time
# 실제 요약문 : very nice
# 예측 요약문 :  works well
#
#
# 원문 :  product great pancakes baked goods blend bisquick pamela bread mix great gluten free dairy free treats bread mix makes less crumbly
# 실제 요약문 : great product
# 예측 요약문 :  great bread
#
#
# 원문 :  great pyrenees eat stuff like crazy tried iams like ate yellow bag puppy wellness really likes large breed formula would definetly recommend dog owners
# 실제 요약문 : better than
# 예측 요약문 :  my dog loves it
#
#
# 실제 요약문 : my son loves these
# 예측 요약문 :  my baby loves this
#
#
# 원문 :  sauce st time trip california years ago stuff amazing perfect amount heat unbelievably good flavor crazy flavors available brand roasted garlic hot sauce right time favorites
# 실제 요약문 : amazingly good hot sauce
# 예측 요약문 :  great sauce
#
#
# 원문 :  first looked package sure enough chocolate trying really liked good balance granola chocolate tastes really good literally sat ate bag discovered negative pretty crumbly small pieces messy eating snack
# 실제 요약문 : really good tasting granola
# 예측 요약문 :  not good
#
#
# 원문 :  love product excited keep ordering product seeds grew order person
# 실제 요약문 : organic and tastes great
# 예측 요약문 :  great product
#
#
# 원문 :  tea tin aroma well taste beautiful flowers soften taste amount bergamot right first time used much tea soaked long since save quantity tea leaves soak tea two minutes delight best earl grey ever price competitive
# 실제 요약문 : great well earl grey
# 예측 요약문 :  tea
#
#
# 원문 :  recommend tea friends clients colds highly recommend anyone reading
# 실제 요약문 : the best tea for your
# 예측 요약문 :  great tea
#
#
# 원문 :  excited find seasoning amazon considering sold currently live lived new mexico used seasoning everything kept right next salt pepper versatile excited use
# 실제 요약문 : best seasoning ever
# 예측 요약문 :  the best
#
#
# 원문 :  huge hit staff receive job well done everything arrived good shape despite summer heat cannot go wrong gift
# 실제 요약문 : wonderful
# 예측 요약문 :  great gift
#
#
# 원문 :  nantucket blend perfect smooth medium blend right amount caffeine wake morning almost creamy almost tastes like slight vanilla flavor take word slightly vanilla definitely coffee connoisseur guess think creamy yummy tasting
# 실제 요약문 : yummy smooth coffee
# 예측 요약문 :  great coffee
#
#
# 원문 :  far best protien bar tried tried alot nutrition roll bar
# 실제 요약문 : nutrition bar
# 예측 요약문 :  delicious
#
#
# 원문 :  never liked cooking honestly never cooked good food however things changed velveeta cheesy skillets tastes good requires minutes prepare served girlfriend could believe cooked lot time cooking still want good meal go one disappointed
# 실제 요약문 : looks and tastes good
# 예측 요약문 :  not bad
#
#
# 원문 :  dog loves treats particular package size sealed size packages product strongly sealed plastic rib must torn remove lid least tape could used around lid size please consider something provide
# 실제 요약문 : dog treats beef liver
# 예측 요약문 :  not for my dogs
#
#
# 원문 :  fan protein bars ordering getting autoship bonus fan processed foods general love kashi need protein boost sometimes quick easy go version
# 실제 요약문 : staple item
# 예측 요약문 :  great cereal
#
#
# 원문 :  know cookies number one good must try
# 실제 요약문 : so good
# 예측 요약문 :  good cookies
#
#
# 원문 :  family members keep kosher vegetarians unable eat gluten etc cookie covers bases tends soft entirely tasty however used make gluten free pie crust great feature feeling baked little longer would better really though good gluten free cookie
# 실제 요약문 : tasty gluten free
# 예측 요약문 :  great cookies
#
#
# 원문 :  ordered father always gets heartburn certain types foods including regular coffee basically great find digestion handle coffee problem blend others commented flavor tastes light may weak though depends whether used overpowered starbucks subtle brews also cheap said worth extra cost enjoy cup morning joe
# 실제 요약문 : great if you have
# 예측 요약문 :  good coffee
#
#
# 원문 :  delighted food looks nice smells really great smaller size kibble old dog teeth comes ziplock pouch importantly though old dog getting little suddenly gotten since starting chow also noticed terrible daily gone fair time switched wet food harmony foods may also factor extremely happy food continue buy
# 실제 요약문 : highly recommend this
# 예측 요약문 :  great food
#
#
# 원문 :  good product hot say pain hot sauce little much vinegar taste also shipping good took little week get house
# 실제 요약문 : hot sauce
# 예측 요약문 :  hot sauce
#
#
# 원문 :  using product last months month old toddler use milk water likes drinking use product plain yogurt grain hot cereal loves chocolate yogurt oatmeal sweet like added vitamins veggies offers low sugar content found find free shipping dollars cheaper buy store
# 실제 요약문 : great food
# 예측 요약문 :  great for
#
#
# 원문 :  best tasting olive oil healthy raw living organic best
# 실제 요약문 : the best
# 예측 요약문 :  great product
#
#
# 원문 :  heard lot coconut water thought would give try wish tried bottle locally rather buying multiple bottles amazon taste really bad cloying aftertaste already tried product would recommend getting small bottle local health food store first
# 실제 요약문 : really nasty tasting stuff
# 예측 요약문 :  not bad
#
#
# 원문 :  get brand size bj half price shipping buy bags time good
# 실제 요약문 : love mango
# 예측 요약문 :  good product
#
#
# 원문 :  wonderful yet overpowering taste gives soups veggies meats little extra taste people keep wondering love afraid gives mild warm sesame flavor depending amount used recommend highly comes drop drop hard
# 실제 요약문 : mild for all foods
# 예측 요약문 :  great product
#
#
# 원문 :  tiny chihuahuas love food made switch beneful due dyes ingredients diamond much healthier comes right door priced good deal
# 실제 요약문 : and approved
# 예측 요약문 :  great product
#
#
# 원문 :  excellent product ten pound chihuahua suffers skin allergies tried food products grain chicken free loves product recommend highly ordered amazon could satisfied
# 실제 요약문 : excellent dog food
# 예측 요약문 :  great product
#
#
# 원문 :  long lists chemical additives either nice find something quick easy feel guilty giving kids time time problem paying little bit premium annie well worth oh anyone getting lumps take package directions face value mix cheese separately add pasta
# 실제 요약문 : no more orange cheese
# 예측 요약문 :  great taste
#
#
# 원문 :  really enjoyed mix tasty bread baking mix pamela also amazing pancakes
# 실제 요약문 : tasty mix
# 예측 요약문 :  best bread mix
#
#
# 원문 :  packages came tiny pits pieces one piece bigger thumb nail picture deceiving texture good overly salty flavor seems like actually taste salmon believe love salty foods drawn would order color salmon rest small salty tell disappointed
# 실제 요약문 : and pieces very salty
# 예측 요약문 :  not as good as expected
#
#
# 원문 :  grass grew really fast two three cats enjoy whether cut put dish leave without creating much mess either way great product cat may love
# 실제 요약문 : pretty how well this grass works
# 예측 요약문 :  cat food
#
#
# 원문 :  used product many years disappointed recent order use summer especially many places visited recognize iced tea
# 실제 요약문 : tea for more than two
# 예측 요약문 :  great product
#
#
# 원문 :  product bite size smaller blue bag except longer links vary length ingredient list somewhat gross lists specific parts pig get past taste slim jim ingredient list disturbing slim jim separate ingredients chicken separated chicken understand one cover
# 실제 요약문 : excellent if you do not read ingredients
# 예측 요약문 :  not as advertised
#
#
# 원문 :  waffle pancake mix delicious taste subtle hint vanilla pancakes waffles kids love house smells wonderful cooking
# 실제 요약문 : great tasting pancakes and waffles
# 예측 요약문 :  best pancakes ever
#
#
# 원문 :  lots coconut flavor grams carbs make lot sense paying per bottle gym never wrong right
# 실제 요약문 : love it
# 예측 요약문 :  coconut oil
#
#
# 원문 :  told friend try tea allergies brought works great quickly long time allergy suffer loves tea able use stopped medications
# 실제 요약문 : really works for
# 예측 요약문 :  great tea
#
#
# 원문 :  amazon sugar free items found love licorice also love menthol decided try never happy freshen mouth delightfully hope flavors
# 실제 요약문 : strong taste and good
# 예측 요약문 :  delicious
#
#
# 원문 :  searched years decaf coffee kept wonderful flavor full bodied coffee finally found tried newman decaf great taste great company happy customer
# 실제 요약문 : best decaf have tried
# 예측 요약문 :  great coffee
#
#
# 원문 :  nothing compares satisfaction drinking plain water mint flat taste waste money reviews far given star makes suspicious
# 실제 요약문 : taste
# 예측 요약문 :  not bad
#
#
# 원문 :  treats definitely dogs favorite gobble started turning treats come fun shapes open smell like peanut butter smell good tempted try ingredients wholesome natural feel good giving dogs wish came box
# 실제 요약문 : best dog treats ever
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  one favorite restaurants serves tea iced kind enough share brand name asked makes wonderful refreshing healthful iced tea highly recommend
# 실제 요약문 : makes great iced tea
# 예측 요약문 :  great tea
#
#
# 원문 :  love water tops break rather annoying limits cannot take opening
# 실제 요약문 : vita coconut water
# 예측 요약문 :  great
#
#
# 원문 :  easily beat coffee true bargain ask get bag treat right
# 실제 요약문 : for there is not for me
# 예측 요약문 :  coffee
#
#
# 원문 :  avid rice cracker fan tried lot different varieties best far taste availability goes obviously best japanese grocery stores least case way time crackers savory crunchy exactly look snack thanks stopped trying regular grocery store
# 실제 요약문 : hard to find better
# 예측 요약문 :  best ever
#
#
# 원문 :  shipped fast great product dog teeth giving poodle greenies years vet said teeth white healthy year old dogs years old
# 실제 요약문 : greenies
# 예측 요약문 :  greenies
#
#
# 원문 :  leery product hooked really easy one pot clean kids loved happy added cut chicken vegetables broccoli snap peas red peppers along bread garden salad perfect dinner moist tasty normally use crock pot liked even better big crock clean quick easy alternative dinner idea kids love eat cheese sauce
# 실제 요약문 : fast easy one dinner
# 예측 요약문 :  great product
#
#
# 원문 :  first tried glass straight strong aromatic coffee smell good dark color strong coffee flavor hint sweetness next heated cup microwave consistent results surprisingly good canned coffee
# 실제 요약문 : tasty hot or cold
# 예측 요약문 :  great coffee
#
#
# 원문 :  really liked tea tastes smooth without bitterness also steeped second time still produce good cup tea price opinion unbeatable fan adagio teas price sencha way expensive one
# 실제 요약문 : good and affordable tea
# 예측 요약문 :  great tea
#
#
# 원문 :  purchasing coffee definatly worth expensive tastes wonderful although get purchase another box husband liked much
# 실제 요약문 : awesome coffee
# 예측 요약문 :  coffee
#
#
# 원문 :  yummy pasta dish like convenience everything need one box made according directions recently save calories put less oil much one half less called find tasty
# 실제 요약문 : tangy and very tasty
# 예측 요약문 :  great taste
#
#
# 원문 :  description say many cups included impossible determine whether good buy like amazon anyone know total number kcups tea offer
# 실제 요약문 : not enough
# 예측 요약문 :  not what expected
#
#
# 원문 :  whole wheat orzo pretty hard find stores try eat whole grain pasta bread etc love texture delicious mind buying jars dried sealed pasta keeps long
# 예측 요약문 :  great tea
#
#
# 원문 :  first bite kind hard bite gosh good kids loved
# 실제 요약문 : my kids loved them
# 예측 요약문 :  not what expected
#
#
# 원문 :  chocolates good quality wonderful taste texture give holiday special occasion chocolates whether buying easter bunny specially wrapped chocolates fresh well made good ingredients buying could find individually wrapped quality halloween chocolate figure orange black wrapper close enough glad found something acceptable made dependable even somewhat fancy brand
# 실제 요약문 : quality chocolate in
# 예측 요약문 :  delicious
#
#
# 원문 :  tried friend house absolutely love since prefer green tea ordered great taste hope quality tea also good love going try flavor
# 실제 요약문 : great taste
# 예측 요약문 :  great tea
#
#
# 원문 :  using tomato paste tubes many years first one tried france love truly double concentrated tomato paste salt ingredients added fantastic add extra rich taste thickness sauces would use regular tomato paste highly recommend product la france give italian tomato used years run money nice big oz tube
# 실제 요약문 : double tomato paste from
# 예측 요약문 :  best olive oil
#
#
# 원문 :  gold kili natural instant ginger lemon beverage mix quite tasty easy put packet crystals cup add water although packet indicate precise amount water filled oz cup tea still strong taste ginger slight hint lemon zing bit kick quite tasty easy take go traveling
# 실제 요약문 : quite tasty with kick
# 예측 요약문 :  refreshing
#
#
# 원문 :  drink mountain dew recently black favorite soda tried change logo add words fruit punch know bad logo change someone unfortunatly yet find substitute times cannot find get
# 실제 요약문 : favorite soda but so hard to find
# 예측 요약문 :  not bad
#
#
# 원문 :  definitely buy salty bad idea great eager low carb snack
# 실제 요약문 : extremely salty
# 예측 요약문 :  not bad
#
#
# 원문 :  favorite tea thing gets morning tea mate hard find supermarket pricey thrilled able subscribe get boxes amazon first set came right time
# 실제 요약문 : morning tea
# 예측 요약문 :  tea
#
#
# 원문 :  great tea like turkey easy mix prepare wife thinks little sweet love
# 실제 요약문 : sour apple tea
# 예측 요약문 :  great tea
#
#
# 원문 :  makes wonderful pina coladas cannot lot sugar drinks weekend cannot wait
# 실제 요약문 : great
# 예측 요약문 :  delicious
#
#
# 원문 :  second time ordered newman organic raisins quite pleased raisins plump tasty right texture received timely manner quite happy product ordering would definitely recommend others
# 실제 요약문 : and
# 예측 요약문 :  great product
#
#
# 원문 :  use work quick easy much better vile coffee provide understand price though oz jar whole foods well exp date
# 실제 요약문 : at whole foods
# 예측 요약문 :  good product
#
#
# 원문 :  greyhounds years old loved lip food given energy coats looking wonderful fact open bag food smells like fruit veg changing small kibbles old food take process older dogs size high quality company never recall products something look today
# 실제 요약문 : my love it
# 예측 요약문 :  good food
#
#
# 원문 :  one favorite coffees believe tried also case others want different ordered brand couple times amazon also costco
# 실제 요약문 : newman own special blend
# 예측 요약문 :  coffee
#
#
# 원문 :  two kids tried various formula brands enfamil similac parent choice kirkland exception similac one kids seem like take brand mostly use kirkland buy bright available sale kids problem sure better worse brands since manufacturers supposed follow fda standards see reason overpriced brand
# 실제 요약문 : best quality for the price
# 예측 요약문 :  good stuff
#
#
# 원문 :  excellent product tastes exactly way want huckleberry fix thing get
# 실제 요약문 : delicious
# 예측 요약문 :  great product
#
#
# 실제 요약문 : if only they were not
# 예측 요약문 :  great gift
#
#
# 원문 :  husband loves energy drinks person buy really fan one since relatively similar ingredients concerned taste thought one great buying
# 실제 요약문 : it is all right
# 예측 요약문 :  great energy drink
#
#
# 원문 :  bought coffeemaker tried several different brands types coffee one become stable count great cup coffee strong mild way like drink coffee probably taste downside
# 실제 요약문 : great coffee
# 예측 요약문 :  great coffee
#
#
# 원문 :  care product thought tea sisters use drink school found tea use drink actually came root particular type tree
# 실제 요약문 : tea
# 예측 요약문 :  not what expected
#
#
# 원문 :  hard crunchy salty hint burnt taste gritty chewing need washed water hoping something like cheetos probably possible pure cheese prefer chips made microwaving slices cheddar positive low carb snack need refrigeration eat run
# 실제 요약문 : weird and
# 예측 요약문 :  not bad
#
#
# 원문 :  best gummi bears buy fresh remain fresh place airtight container open great price always favorites
# 실제 요약문 : haribo gummi bears the best
# 예측 요약문 :  haribo gummi bears
#
#
# 원문 :  like brand size cans leftover tuna good disagree previous comments think fishy would compare cat food tried brands dislike top smell mushy textures like chicken sea buy frequently
# 실제 요약문 : prefer chicken of the sea
# 예측 요약문 :  good but not
#
#
# 원문 :  got bags sams club hours placed order bags ish way cancel next time pay closer attention fine print bottom line per bag compared sams per bag hard find multiple chip bags went makes waste
# 실제 요약문 : rip off
# 예측 요약문 :  not as pictured
#
#
# 원문 :  felt really good good cat mommy buying something quality bad none would eat matter donated local maybe dog eat
# 실제 요약문 : it would be nice it they it
# 예측 요약문 :  cat food
#
#
# 원문 :  pros juice corn syrup extra sugar added gluten cans small price way high sweet tasting refreshing conclusion probably would recommend
# 실제 요약문 : did not like it
# 예측 요약문 :  not bad
#
#
# 원문 :  imagine took raspberry drizzled chocolate syrup put frying pan turned frying pan let hours put coffee filter brew sound good think thats coffee tastes like bought double pack like tried like even gave second shot wish knew rest would subject friends cannot give
# 실제 요약문 : tastes like raspberry
# 예측 요약문 :  great product
#
#
# 원문 :  almost expired got ordered like share family country take time package get figured time expired sense ordering many package still better get grocery store check expiration date
# 실제 요약문 : expiration date is almost there
# 예측 요약문 :  expired
#
#
# 원문 :  tea excellent flavor reuse tins buying larger quantities bulk storing tins tea station counter tin tin earl gray always hand note prefer tea iced use coffee filter iced tea maker disappointed
# 실제 요약문 : excellent flavor love the
# 예측 요약문 :  great tea
#
#
# 원문 :  far best cheese popcorn ever eaten husband addicted stuff always fresh really flavorful wow
# 실제 요약문 : cheesy
# 예측 요약문 :  great popcorn
#
#
# 원문 :  high hopes product like splenda normally drink diet soda anyway feel like used taste non diet soda drinkers complain unfortunately awful first sip rd could take funky taste anymore throw may still try another flavor hope different result definitely recommend pina colada mix
# 실제 요약문 : terrible after taste
# 예측 요약문 :  not bad
#
#
# 원문 :  costs many grains cats supposed diet like eat like candy must flavoring
# 실제 요약문 : and not healthy but cats love it
# 예측 요약문 :  cats love it
#
#
# 원문 :  good variety flavors makes helpful sample choice type prefer also good packed lunches portioned snack
# 실제 요약문 : pop chips flavor variety pack
# 예측 요약문 :  great for
#
#
# 원문 :  great service fast ordered item tasted great fresh trouble shipping fault extremely helpful pleasure deal
# 실제 요약문 : wonderful service great
# 예측 요약문 :  great gift
#
#
# 원문 :  everybody information coconut water made philippines brazil claimed brazilian developed business coconuts came philippines vita coco pure coconut water ounce containers
# 실제 요약문 : coconut
# 예측 요약문 :  not bad
#
#
# 원문 :  bought product looked good knowing would taste good looked well finally showed usps well packaged soft smells great tastes even better disappointed already eaten five strips
# 실제 요약문 : looks good and tastes good
# 예측 요약문 :  not what expected
#
#
# 원문 :  dogs like probably main point hard time finding non dry dog food treats put inside toy still dogs seemed jolly time complain lack treat variety
# 실제 요약문 : treat toy
# 예측 요약문 :  my dog loved it
#
#
# 원문 :  bought give homeless people street seem really appreciate nice thing melt goo put pocket
# 실제 요약문 : perfect little gift that does not
# 예측 요약문 :  great product
#
#
# 원문 :  love brand would buy anything different spices perfect best vanilla soymilk makes day
# 실제 요약문 : cannot live without it
# 예측 요약문 :  great
#
#
# ...
# 예측 요약문 :  great tea
#
#
# 원문 :  would buying four pack melitta french vanilla coffee month past years last month changed packaging fine also changed grind sudden four packs come extra fine grind simply work well drip coffee maker whole pot tastes weak get last couple cups taste like mud coffee settled hoping switch back point bad
# 실제 요약문 : ground too fine
# 예측 요약문 :  not as advertised
#
#
# 원문 :  discovered fiber really makes difference way feel perform one bowl golean gotten third daily target really hard one item golean stays firm milk small enough chewed easily without pushing sides mouth goes well added fruit oh yes tastes fine
# 실제 요약문 : fiber
# 예측 요약문 :  great product
#
#
# 원문 :  bought lbs belly back good sweet jelly beans sweet tasty seems lot root beer beans ones come bags box jelly beans value good money future going stick
# 실제 요약문 : not as good as
# 예측 요약문 :  best gum ever
#
#
# 원문 :  green tea husband drink spices wonderful cover flavor green tea make aromatic cup complaint expensive quantity buying tea bags packaged bought tea bulk packaged bag much cheaper per pound buy bulk think product mostly paid small amount tea inside least nice found way use store cat treats
# 실제 요약문 : spicy and delicious
# 예측 요약문 :  tea
#
#
# 원문 :  year old loves squeeze applesauce looking healthier alternative loves plum baby blends one would eat grainy texture bland taste
# 실제 요약문 : my toddler would not eat
# 예측 요약문 :  my baby loves this
#
#
# 원문 :  good stuff almost buck cup cheaper buying cup coffee house get drink one favorite coffees
# 실제 요약문 : good but expensive
# 예측 요약문 :  great coffee
#
#
# 원문 :  bars delicious full protein walnuts almonds protective cancer great use candy give voice middle east company worthy support
# 실제 요약문 : best product in the
# 예측 요약문 :  great snack
#
#
# 원문 :  cat turned nose neighbor cats gave rest case buy
# 실제 요약문 : most cats will not eat this
# 예측 요약문 :  cats love it
#
#
# 원문 :  bought thinking could save money taste poor really taste good used times throw soon go grocery store buy another brand
# 실제 요약문 : not that great
# 예측 요약문 :  not what expected
#
#
# 원문 :  kids enjoyed granola nice fresh taste chocolate bonus daughter normally eat granola put homemade ice cream gobbled ate cereal milk enjoyed happy every back nature product purchased exception would buy
# 실제 요약문 : fresh flavor
# 예측 요약문 :  great granola
#
#
# 원문 :  first dessert italy class finished reading lion enjoyed dismay could find returned states came magic internet finally found brought back wonderful memories taste light sweet happy able order whenever want
# 실제 요약문 : absolutely
# 예측 요약문 :  delicious
#
#
# 원문 :  one favorites tassimo medium flavor coffee would say coffee expert like automatically set tassimo make oz cup instead oz cup great flavor morning
# 실제 요약문 : morning roast
# 예측 요약문 :  great coffee
#
#
# 원문 :  hit bitter like maybe carrots sweet peeled main ingredient carrots quality control seems issue second gourmet meal flavor issue never bad experience eb products disappointing
# 실제 요약문 : bitter and
# 예측 요약문 :  not bad
#
#
# 원문 :  almonds arrived quickly nice big bag good fresh almonds lots go brownies days back put one already eating tasty
# 실제 요약문 : good deal
# 예측 요약문 :  best almonds
#
#
# 원문 :  holidays would festive without chestnuts especially dessert called chocolate heavy cream chestnuts combination cannot improved upon add little set holiday gift
# 실제 요약문 : delicious
# 예측 요약문 :  great gift
#
#
# 원문 :  great pancake mix almost corn texture rate everything son eat super picky loves pancakes tried making biscuits mix turn well far pancakes rocks
# 실제 요약문 : great pancakes
# 예측 요약문 :  great for
#
#
# 원문 :  love yuban one better ones maxwell house also bad ones pretty decent yuban rich robust stronger coffees tried yet bitter overall recommend
# 실제 요약문 : great coffee for the price
# 예측 요약문 :  good coffee
#
#
# 원문 :  dog loves checkups small dog cut give one third dinner day
# 실제 요약문 : my dog loves them
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  makes good quick meal flatbread rice found adding liquid milk tasty soup could undoubtedly make something better fresh ingredients always convenience line hard beat
# 실제 요약문 : convenient and tasty
# 예측 요약문 :  great product
#
#
# 원문 :  bars melted arrived chocolate coating gray bars taste like cardboard would never order
# 실제 요약문 : not good
# 예측 요약문 :  stale
#
#
# 원문 :  buy dog loves treat however found made china decide throw away remaining portion want take chances see someone left review saying dog got sick eating treat luckily dog fine still buy
# 실제 요약문 : made in china
# 예측 요약문 :  not
#
#
# 원문 :  always loved gummis thought know real gummi treat taste like mention texture freshness never go back brand love haribo treats fact ration otherwise family go lb bag days huge savings store fine ziploc tupperware
# 실제 요약문 : wonderful treat
# 예측 요약문 :  these are the best
#
#
# 원문 :  dressing would hard pressed find another dressing tastes good calories sugar love salads love put hamburgers make big mac give try want sorry
# 실제 요약문 : good stuff and no sugar or
# 예측 요약문 :  best mix
#
#
# 원문 :  diabetes runs family always looking sugar free treats everyone family loved even nephews ages gross taste variety neat flavors went bought pound bag pound enough
# 실제 요약문 : yum
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  delicious cold cereal around great crunch terrific flavor enough dried fruit minimal sweetening happily corn syrup high fructose corn syrup expensive worth
# 실제 요약문 : crunch
# 예측 요약문 :  great cereal
#
#
# 원문 :  reading reviews decided purchase husband husband drinks tea every day prefers stronger blends like one used drink pg tips tried barry tea prefers barry looking nice strong basic tea look
# 실제 요약문 : my husband favorite everyday tea
# 예측 요약문 :  great tea
#
#
# 원문 :  buy yorkies beautiful hair healthy hearts love salmon paws broccoli diarrhea salmon broccoli good sensitive digestive systems nice chewy texture teeth easily broken big plus tiny mouths seller prompt never problem
# 실제 요약문 : love these
# 예측 요약문 :  my dogs love these
#
#
# 원문 :  buying mini bones amazon sold brand name could find brand anymore started buying brand since smell bones different dogs would eat dip milk first love glad small bones discontinued since easy chew
# 실제 요약문 : my dogs love the mini bones
# 예측 요약문 :  my dog loves these
#
#
# 원문 :  brewing tea chilled served iced tea good hot summer afternoon
# 실제 요약문 : nice tangy tea
# 예측 요약문 :  great tea
#
#
# 원문 :  pretty substantial cookie decent amount fiber conveniently packaged work school calories per cookie diet food opinion gourmet treat dry soft cookie pleasant chocolate almond flavor decent choice school lunch th go snack satisfy cookie lover wanting treat
# 실제 요약문 : lunch snack
# 예측 요약문 :  not bad
#
#
# 원문 :  ordered product themed baby shower went well tasted like normal cracker jacks loved could find box fit perfect favor bags
# 실제 요약문 : was perfect
# 예측 요약문 :  love these
#
#
# 원문 :  normal oregon chai good fond chai get certain chain coffee shops seattle want chai almost burning sensation much cheaper convenient make sure pick pump well
# 실제 요약문 : if you are looking for robust chai
# 예측 요약문 :  great chai
#
#
# 원문 :  weak tasting product watered hot chocolate best hoping would gold product would enjoy purchase
# 실제 요약문 : weak hot chocolate
# 예측 요약문 :  not bad
#
#
# 원문 :  delicious smoothie mix comes creamy add frozen fruit yogurt protein powder whatever else like best mix tasted
# 실제 요약문 : wonderful mix
# 예측 요약문 :  best ever
#
#
# 원문 :  family loves granola whether sprinkling yogurt eating bowl milk great taste ounce bags excellent value
# 실제 요약문 : great product
# 예측 요약문 :  great cereal
#
#
# 원문 :  great way better snickers healthier great carry one day way something safe eat chocolate
# 실제 요약문 : no need to eat candy bars again
# 예측 요약문 :  great
#
#
# 원문 :  cheaper coffees probably tried good percentage always end coming back folgers something natural maybe used prices folgers vary greatly stores deal better amazon would recommend price
# 실제 요약문 : the best of up
# 예측 요약문 :  good coffee
#
#
# 원문 :  arrived well packaged fresh looking good enough expiration date box pricier could bought locally
# 실제 요약문 : fresh and
# 예측 요약문 :  great gift
#
#
# 원문 :  seasoning good texture liking almost spongy microwaving improve texture little dry chewy weird aftertaste tried versions jerky prefer dry chewy veggie jerky would go vegan dream brand sampler pack different flavors also follow weight watchers online oz package points grams fat calories grams fiber lower calorie veggie available concern
# 실제 요약문 : not my favorite
# 예측 요약문 :  not bad
#
#
# 원문 :  love gevalia signature crema coffee rich taste incredible foam created automatically perfect taste auto delivery never run
# 실제 요약문 : my favorite coffee
# 예측 요약문 :  great coffee
#
#
# 원문 :  creamy smooth coconut milk nice rich taste almost like also soft creamy chunks delicious use pancakes curries add bit vanilla sweetener make great frozen dessert love stuff
# 실제 요약문 : delicious
# 예측 요약문 :  great chai
#
#
# 원문 :  good job new packaging still go soggy unless wrap wrap need pair scissors open good job
# 실제 요약문 : new packaging
# 예측 요약문 :  great service
#
#
# 원문 :  bake lot vegan cookies quick breads muffins pumpkin great ingredient add moisture flavor grocery store canned pumpkin half time turned amazon discovered brand process flavor good price great always prefer buy organic non big plus ordered two cases thus far definitely reorder run
# 실제 요약문 : great item
# 예측 요약문 :  great pasta
#
#
# 원문 :  bought trader joes pretty hard maybe old others said hard chewy hurt jaw taste ok chocolatey hoped caramel good pretty sticky got fingers nuts things outside pretty good kept falling onto floor guess try less messy kashi bar next time
# 실제 요약문 : hard and chewy
# 예측 요약문 :  not bad
#
#
# 원문 :  tell dog loves almost food eats straight cannot honestly tell anything food except dog loves looking package bowl wife make comment dog food looks better lot stews casseroles eaten
# 실제 요약문 : my dog loves it
# 예측 요약문 :  good food
#
#
# 원문 :  like coffee people coffee love coffee better price cups morning brew use starbuck cafe verona donut shop coffee people choice breakfast blend gets going
# 실제 요약문 : great coffee great price
# 예측 요약문 :  coffee
#
#
# 원문 :  love stuff tastes like real peanut butter fat calories using peanut butter jelly protein shakes etc
# 실제 요약문 : amazing
# 예측 요약문 :  great taste
#
#
# 원문 :  need lot words review honey tastes better healthier less expensive store bought honey usual amazon service great
# 실제 요약문 : stuff
# 예측 요약문 :  great product
#
#
# 원문 :  great product takes flavor whatever cooked get mushy stays nice firm simple prepare one package enough person
# 실제 요약문 : miracle noodle hair pasta
# 예측 요약문 :  not bad
#
#
# 원문 :  first harney sons paris tea resort oregon may rainy cold sick looked forward tea morning amazing aroma flavor incredibly soothing ordered online shortly getting home favorite tea ever ran sachets saved tin little secret occasionally open tin take whiff smells good
# 실제 요약문 : tea is my favorite
# 예측 요약문 :  best tea ever
#
#
# 원문 :  tried cereal right box milk tasted pretty good really sweet tried milk tasted pretty good awhile cereal gave milk taste little different flavor cereal milk made taste little overall cereal bad really anything much different many cereals already market tend eat cereals lot less sweet pass one
# 실제 요약문 : not bad but
# 예측 요약문 :  great taste
#
#
# 원문 :  seeds produced plants wheatgrass growing could easier happy purchase
# 실제 요약문 : as
# 예측 요약문 :  good product
#
#
# 원문 :  smell vanilla extract says flavor baking comes nicely flavor secret ingredient many delicious baked goods aroma fantastic
# 실제 요약문 : the best vanilla extract
# 예측 요약문 :  great taste
#
#
# 원문 :  like delivered free shipping two flavors per shipment think pedigree good name dogs love convenient even like going shop anymore
# 실제 요약문 : happy puppy dogs
# 예측 요약문 :  good product
#
#
# 원문 :  excellent tasting tea fact decaf sugar free makes delicious back
# 실제 요약문 : delicious product
# 예측 요약문 :  great tea
#
#
# 원문 :  coworker bought target shared found nuts delicious addictive searched online see could purchase target ran
# 실제 요약문 : delicious flavored cashews
# 예측 요약문 :  delicious
#
#
# 원문 :  love hawaiian shaved ice much better brands found local stores star flavor lot tiger blood
# 실제 요약문 : great syrup
# 예측 요약문 :  great taste
#
#
# 원문 :  iced green tea great quick glass iced tea go hassle making whole pitcher make one glass time convenient keep bunch glasses freezer water refrigerator grab mug pour powdered green tea powder individual packet add cold water frig stir drink refreshing
# 실제 요약문 : perfect cold drink for hot day
# 예측 요약문 :  love this tea
#
#
# 원문 :  actually seem vary batch sometimes excellent sometimes lack little flavor still like continue buy high recipe
# 실제 요약문 : good and easy
# 예측 요약문 :  good stuff
#
#
# 원문 :  one smoothest extra dark chocolates tried compared much higher prices brands like el etc darn good cocoa goodness
# 실제 요약문 : very smooth bargain for the price
# 예측 요약문 :  great coffee
#
#
# 원문 :  like indian food like curry want quick meal think vegetarian also mix minute rice microwave white rice leftover cooked might smash bit add also better price could get store buy amazon subscribe plan get free shipping
# 실제 요약문 : pretty good
# 예측 요약문 :  great product
#
#
# 원문 :  excited try favorite treat past delivery box mallomars disappointed marshmallow center remembered fluffy soft creamy yummy chocolate flavor also good marshmallow chocolate spongy cookie always great combination also like bit size problem hard stop eating almost finished box criticism nearly box price
# 실제 요약문 : very good but little pricey
# 예측 요약문 :  delicious
#
#
# 원문 :  amazing concept fried even baked popped like popcorn another product weight watchers bag points love snack mid morning breakfast lunch taste really good favorite bar que salt vinegar sour cream good though
# 실제 요약문 : excellent thumbs up
# 예측 요약문 :  great product
#
#
# 원문 :  candies fresh delicious one imagine served heaven bought friends everyone raves biting nice sized pieces candy event
# 실제 요약문 : taste of heaven
# 예측 요약문 :  yummy
#
#
# 원문 :  one favorites carry lemon ginger travel good stomach aroma refreshing especially sitting plane
# 실제 요약문 : absolutely delicious
# 예측 요약문 :  great tea
#
#
# 원문 :  hi black tea everyday done past years habit mine ahmad tea one favorite brands highly recommend like black tea think going remain favorite next years
# 실제 요약문 : my everyday cup of tea
# 예측 요약문 :  great tea
#
#
# 원문 :  oh mess old version tastes nothing like used chewy sweet strange mouth feel anyone recommend bar tastes like previous recipe done lindt
# 실제 요약문 : why
# 예측 요약문 :  not bad
#
#
# 원문 :  dogs love peanut butter crackers last one finally came around eats seem little dry think go waste price good shipping time fine
# 실제 요약문 : dog treats
# 예측 요약문 :  not for my dog
#
#
# 원문 :  go use white tea slight taste odor use anymore may like fine
# 실제 요약문 : use
# 예측 요약문 :  tea
#
#
# 원문 :  bought safeway swiss chocolate almond coffee ok seller great product received time quality taste ok
# 실제 요약문 : it is not but it is ok
# 예측 요약문 :  not bad
#
#
# 원문 :  masala helped make great chicken spices fresh fragrant made delicious dinner would recommend others
# 실제 요약문 : makes great chicken
# 예측 요약문 :  great product
#
#
# 원문 :  picky comes coffee like mine strong good flavor become coffee tried plenty
# 실제 요약문 : best up coffee every
# 예측 요약문 :  good coffee
#
#
# 원문 :  everything thought would served parents daughters rd birthday party loved definetly ordering
# 실제 요약문 : yummy yummy yummy
# 예측 요약문 :  great product
#
#
# 원문 :  easily bag great snack run aware contains two servings plan accordingly love auto ship gets cheaper longer stay good deal
# 실제 요약문 : yummy
# 예측 요약문 :  yummy
#
#
# 원문 :  cracker seem healthy side hard rock buying
# 실제 요약문 : very
# 예측 요약문 :  these are the best
#
#
# 원문 :  love flavors organic smoothie fruits subscribe save perfect way get yellow one red one monthly basis little one eats directly hard spout
# 실제 요약문 : great snack for little ones
# 예측 요약문 :  love this stuff
#
#
# 원문 :  great energy beverage truly healthy free unnecessary additives body better faster water working head straight zico refrigerator
# 실제 요약문 : love at first
# 예측 요약문 :  great taste
